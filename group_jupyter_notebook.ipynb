# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/3b/bc/4b18e2b8c002572c5a441a64826252ce5da2aa738855747247a971988043/pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/97/e7/7d55a86719d0de7a6a597949f3febefb1009435b79ba510ff32f05a8c1d7/numpy-2.2.3-cp313-cp313-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 489.8 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 415.1 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 411.7 kB/s eta 0:00:00
# ...

# %%
import pandas as pd
world_df = pd.read_csv("worldometer_data.csv")
print("Worldometer info - by sarah")
print(worldodf.info(), '\n')
# Out:
# Worldometer info - by sarah
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 worldomter_df = pd.read_csv("worldometer_data.csv")
#       3 print("Worldometer info - by sarah")
# ----> 4 print(worldometer_df.info(), '\n')
#
# NameError: name 'worldometer_df' is not defined
