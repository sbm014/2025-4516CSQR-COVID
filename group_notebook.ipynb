# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
day_wise_df = pd.read_csv("day_wise.csv")
print("Day Wise Dataset Info - Salem")
print(day_wise_df.info(), "\n")
# Out:
# Day Wise Dataset Info - Salem
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB
# None

# %%
# loading the remaining datasets
worldometer_df = pd.read_csv("worldometer_data.csv")
country_wise_df = pd.read_csv("country_wise_latest.csv")
covid_clean_df = pd.read_csv("covid_19_clean_complete.csv")

print("Worldometer Data Info")
print(worldometer_df.info())
print()

print("Country Wise Latest Date Info:")
print(country_wise_df.info())
print()

print("Covid Clean Complete Data Info: ")
print(covid_clean_df.info())
print()
# Out:
# Worldometer Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
# ...

# %%
#showing missing values of each DataFrame.
print(day_wise_df.isnull().sum())
# Out:
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# No. of countries          0
# dtype: int64

# %% [markdown]
# The Above DataFrame "day_wise_df" shows that there are none missing and null values.

# %%
print(worldometer_df.isnull().sum())
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %% [markdown]
# Worldometer DataFrame has missing values, let us visualize the percentage of missing values.

# %%
pip install missingno
# Out:
# ...
#   Obtaining dependency information for missingno from https://files.pythonhosted.org/packages/87/22/cd5cf999af21c2f97486622c551ac3d07361ced8125121e907f588ff5f24/missingno-0.5.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/89/06/f570373d24d93503988ba8d04f213a372fa1ce48381c5eb15da985728498/matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/0d/76/77cf2ac1f2a9cc00c073d49e1e16244e389dd88e2490c91d84e1e3e4d126/scipy-1.15.2-cp313-cp313-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------- ------------------- 30.7/60.8 kB 97.5 MB/s eta 0:00:01
#      ------------------- ------------------- 30.7/60.8 kB 97.5 MB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 227.9 kB/s eta 0:00:01
# ...

# %%
import missingno as msno
msno.matrix(worldometer_df)
# Out:
# <Axes: >

# %%
print(worldometer_df.columns)
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
revised_worldometer_df = worldometer_df.drop(columns=['NewCases', 'NewDeaths', 'NewRecovered'])

# %%
msno.matrix(revised_worldometer_df)
# Out:
# <Axes: >

# %%
# printing missing values of country wise df
print(country_wise_df.isnull().sum())
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# The Country wise df has none null or missing values

# %%
#printing missing values of covid clean datase
print(covid_clean_df.isnull().sum())
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# The Province state is showing a huge percentage of null values. Let us see first few rows

# %%
print(covid_clean_df.head())
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
print(country_wise_df.isnull().sum())
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
print(country_wise_df.head())
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
print(country_wise_df.describe())
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Select relevant columns for Death and Recovery Rates
df_rates = country_wise_df[["Country/Region", "Deaths / 100 Cases", "Recovered / 100 Cases"]].copy()

# Rename columns for clarity
df_rates.rename(columns={"Deaths / 100 Cases": "Death Rate (%)", "Recovered / 100 Cases": "Recovery Rate (%)"}, inplace=True)

# Sort data in ascending order by Death Rate
df_rates = df_rates.sort_values(by="Death Rate (%)", ascending=True)

# Plot the Death Rate and Recovery Rate as line graphs
plt.figure(figsize=(14, 7))
plt.plot(df_rates["Country/Region"], df_rates["Death Rate (%)"], marker='o', linestyle='-', color='red', label="Death Rate (%)")
plt.plot(df_rates["Country/Region"], df_rates["Recovery Rate (%)"], marker='s', linestyle='--', color='green', label="Recovery Rate (%)")

# Formatting the chart
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Rate (%)", fontsize=12)
plt.title("Death and Recovery Rates by Country (Sorted by Death Rate)", fontsize=14)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# As the graph is oversized and we cannot see and distinguish between the country names, so let us visualize the countries who has recovery rate above average

# %%
who_region_counts = country_wise_df["WHO Region"].value_counts()
# Convert to DataFrame for better readability
who_region_df = who_region_counts.to_frame().reset_index()
who_region_df.columns = ["WHO Region", "Count"]

# Display the DataFrame
print(who_region_df)
# Out:
#               WHO Region  Count
# 0                 Europe     56
# 1                 Africa     48
# 2               Americas     35
# 3  Eastern Mediterranean     22
# 4        Western Pacific     16
# 5        South-East Asia     10

# %%
# Install required libraries (Run this cell once)
# !pip install pandas matplotlib

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Aggregate Death and Recovery Rates by WHO Region
who_region_rates = country_wise_df.groupby("WHO Region")[["Deaths / 100 Cases", "Recovered / 100 Cases"]].mean().reset_index()

# Rename columns for clarity
who_region_rates.rename(columns={"Deaths / 100 Cases": "Average Death Rate (%)", 
                                 "Recovered / 100 Cases": "Average Recovery Rate (%)"}, inplace=True)

# Plot the line graph
plt.figure(figsize=(10, 5))
plt.plot(who_region_rates["WHO Region"], who_region_rates["Average Death Rate (%)"], 
         marker='o', linestyle='-', color='red', label="Average Death Rate (%)")
plt.plot(who_region_rates["WHO Region"], who_region_rates["Average Recovery Rate (%)"], 
         marker='s', linestyle='--', color='green', label="Average Recovery Rate (%)")

# Formatting the chart
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("WHO Region", fontsize=12)
plt.ylabel("Rate (%)", fontsize=12)
plt.title("Average Death and Recovery Rates by WHO Region", fontsize=14)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [raw]
# Insight# 2: Top 10 countries with the highest number of recorded cases.

# %% [markdown]
# Looking an overview again of the Worldometer dataset to work on the insight...

# %%
print(worldometer_df.head())
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
# Install required libraries (Run this cell once)
# !pip install pandas matplotlib seaborn

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
#worldometer_df = pd.read_csv("/mnt/data/worldometer_data.csv")

# Ensure 'TotalCases' column is numeric
worldometer_df["TotalCases"] = pd.to_numeric(worldometer_df["TotalCases"], errors="coerce")

# Select top 10 countries with highest total cases
top_10_cases = worldometer_df.nlargest(10, "TotalCases")

# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_cases["Country/Region"], y=top_10_cases["TotalCases"], palette="viridis")

# Formatting the chart
plt.xlabel("Country", fontsize=12)
plt.ylabel("Total Recorded Cases", fontsize=12)
plt.title("Top 10 Countries with Highest Total Cases", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# C:\Users\Sara\AppData\Local\Temp\ipykernel_23868\3872690025.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_cases["Country/Region"], y=top_10_cases["TotalCases"], palette="viridis")

# %% [markdown]
# Modifying the above code to show label on each bar and revising the Y-Axis labels

# %%
# Ensure 'TotalCases' column is numeric
worldometer_df["TotalCases"] = pd.to_numeric(worldometer_df["TotalCases"], errors="coerce")

# Select top 10 countries with highest total cases
top_10_cases = worldometer_df.nlargest(10, "TotalCases").copy()

# Convert 'TotalCases' to millions for better readability
top_10_cases["TotalCases_Million"] = top_10_cases["TotalCases"] / 1_000_000

# Plot the bar chart
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_10_cases["Country/Region"], y=top_10_cases["TotalCases_Million"], palette="viridis")

# Add labels on each bar
for index, value in enumerate(top_10_cases["TotalCases_Million"]):
    plt.text(index, value + 0.1, f"{value:.2f}M", ha='center', fontsize=12, fontweight='bold')

# Formatting the chart
plt.xlabel("Country", fontsize=12)
plt.ylabel("Total Recorded Cases (in Million)", fontsize=12)
plt.title("Top 10 Countries with Highest Total Cases", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# C:\Users\Sara\AppData\Local\Temp\ipykernel_23868\3902210005.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_10_cases["Country/Region"], y=top_10_cases["TotalCases_Million"], palette="viridis")
